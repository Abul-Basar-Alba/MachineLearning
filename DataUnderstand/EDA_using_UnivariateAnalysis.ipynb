# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.csv')

# %%
sns.countplot(x=df['Survived'])
plt.show()

# %%
sns.countplot(x='Survived', data=df, palette='Set2')  # color change
plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipykernel_2912/2354675749.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=df, palette='Set2')  # color change

# %%
counts = df['Pclass'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Survival Distribution")
plt.show()

# %%
plt.hist(df['Age'],bins=60)
# Out:
# (array([14., 16., 10.,  4.,  6.,  4.,  8.,  6.,  1.,  2., 12., 17., 13.,
#         26., 40., 25., 27., 46., 24., 18., 43., 22., 27., 35., 17., 16.,
#         40.,  7., 11., 27.,  8., 13., 14., 14.,  3., 18.,  6., 10., 13.,
#          1.,  8.,  7.,  2.,  5.,  6.,  3.,  4.,  4.,  3.,  1.,  0.,  0.,
#          3.,  2.,  0.,  1.,  0.,  0.,  0.,  1.]),
#  array([ 0.42      ,  1.74633333,  3.07266667,  4.399     ,  5.72533333,
#          7.05166667,  8.378     ,  9.70433333, 11.03066667, 12.357     ,
#         13.68333333, 15.00966667, 16.336     , 17.66233333, 18.98866667,
#         20.315     , 21.64133333, 22.96766667, 24.294     , 25.62033333,
#         26.94666667, 28.273     , 29.59933333, 30.92566667, 32.252     ,
#         33.57833333, 34.90466667, 36.231     , 37.55733333, 38.88366667,
#         40.21      , 41.53633333, 42.86266667, 44.189     , 45.51533333,
#         46.84166667, 48.168     , 49.49433333, 50.82066667, 52.147     ,
# ...

# %%
sns.histplot(data=df, x='Age', bins=30, kde=True, color='purple')
plt.title("Age Distribution (Histogram + KDE)")
plt.show()

# %%
sns.histplot(data=df, x='Age', hue='Survived', bins=30, kde=True, palette='Set2')
plt.title("Age Distribution by Survival (Histogram + KDE)")
plt.show()

# %%
sns.boxplot(x='Age', data=df)
plt.title("Age Distribution (Box Plot)")
plt.show()

# %%
sns.boxplot(x='Survived', y='Age', data=df, palette='Set2')
plt.title("Age Distribution by Survival")
plt.show()
# Out:
# /tmp/ipykernel_2912/3387557870.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Survived', y='Age', data=df, palette='Set2')

# %%
sns.boxplot(x='Sex', y='Fare', hue='Survived', data=df, palette='Set3')
plt.title("Fare Distribution by Sex and Survival")
plt.show()

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)
