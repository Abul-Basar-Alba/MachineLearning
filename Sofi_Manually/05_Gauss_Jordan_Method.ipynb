# %% [markdown]
# # Gauss-Jordan Elimination Method
#
# Gauss-Jordan Elimination extends Gaussian Elimination by continuing the elimination process to create a reduced row echelon form (identity matrix), eliminating the need for back substitution.
#
# **Process:**
# 1. Make diagonal element = 1
# 2. Make all other elements in that column = 0 (both above and below)
# 3. Repeat for all columns
# 4. Solution appears directly in the augmented column
#
# **Advantage:** No back substitution needed!

# %%
import matplotlib.pyplot as plt

# %%
# Augmented matrix [A|b]
arr = [
    [2, 1, -1, 8],
    [-3, -1, 2, -11],
    [-2, 1, 2, -3]
]
N = 3  # number of unknowns

def gauss_jordan(arr, N):
    solutions_steps = []
    
    for i in range(N):
        for j in range(N):
            if i != j:
                p = arr[j][i] / arr[i][i]
                for k in range(N+1):
                    arr[j][k] -= arr[i][k] * p
        # Store current solution estimates for plotting
        current_solutions = [arr[x][N] / arr[x][x] for x in range(N)]
        solutions_steps.append(current_solutions.copy())
        
        print(f"After step {i+1}:")
        for row in arr:
            print(row)
        print()
    
    # Extract final solutions
    solutions = [arr[i][N] / arr[i][i] for i in range(N)]
    print("Final Solutions:", solutions)
    
    return solutions, solutions_steps

# %%
# Run Gauss-Jordan
solution, steps = gauss_jordan(arr, N)
# Out:
# Solving using Gauss-Jordan Elimination:
# 2x + y - z = 8
# -3x - y + 2z = -11
# -2x + y + 2z = -3
#
# Initial Augmented Matrix [A|b]:
# [[  2.   1.  -1.   8.]
#  [ -3.  -1.   2. -11.]
#  [ -2.   1.   2.  -3.]]
#
# Swapped row 0 with row 1
# After processing column 1:
# [[ 1.          0.33333333 -0.66666667  3.66666667]
#  [ 0.          0.33333333  0.33333333  0.66666667]
#  [ 0.          1.66666667  0.66666667  4.33333333]]
# Current solutions: ['3.6667', '0.0000', '0.0000']
#
# Swapped row 1 with row 2
# After processing column 2:
# [[ 1.   0.  -0.8  2.8]
#  [ 0.   1.   0.4  2.6]
#  [ 0.   0.   0.2 -0.2]]
# Current solutions: ['2.8000', '2.6000', '0.0000']
#
# After processing column 3:
# [[ 1.  0.  0.  2.]
#  [ 0.  1.  0.  3.]
#  [ 0.  0.  1. -1.]]
# Current solutions: ['2.0000', '3.0000', '-1.0000']
#
# Final Solution Vector:
# x = [ 2.  3. -1.]

# %%
# Plotting
variables = ['x', 'y', 'z']
for i, step in enumerate(steps):
    plt.bar([v + f" (step {i+1})" for v in variables], step, alpha=0.7, label=f'Step {i+1}')

plt.ylabel("Value")
plt.title("Gauss-Jordan Elimination Steps")
plt.grid(axis='y')
plt.legend()
plt.show()
