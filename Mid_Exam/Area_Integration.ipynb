# %% [markdown]
# # Trapezoidal Rule

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 1 / (1 + x**2)

def trapezoidal(a, b):
    return (b - a) * (f(a) + f(b)) / 2

a, b = 0, 6
I = trapezoidal(a, b)

x = np.linspace(a, b, 100)
plt.plot(x, f(x), 'b', label='f(x)')
plt.fill_between([a, b], [f(a), f(b)], color='skyblue', alpha=0.4)
plt.title("Trapezoidal Rule")
plt.legend()
plt.show()

print("Trapezoidal =", I)
# Out:
# Trapezoidal = 3.0810810810810807

# %%
a,b = 8,30
I = (b-a)*(f(a)+f(b))/2
# True value from Simpson 3/8
E_true = I - S  # compute true value if known
abs_rel = abs(E_true)/I*100
plt.plot([a,b],[f(a),f(b)],'o-'); plt.show()
print("Trapezoidal =", I, "True error =", E_true, "Abs Rel % =", abs_rel)
# Out:
# Trapezoidal = -2499.925181015888 True error = 80.68785125439626 Abs Rel % = -3.227610644795672

# %% [markdown]
# # Simpson’s 1/3 Rule

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 1 / (1 + x**2)

def simpson_13(a, b):
    h = (b - a) / 2
    x1 = a + h
    return (b - a) * (f(a) + 4*f(x1) + f(b)) / 6

a, b = 0, 6
I = simpson_13(a, b)

x = np.linspace(a, b, 100)
plt.plot(x, f(x), 'g', label='f(x)')
plt.fill_between(x, f(x), color='lightgreen', alpha=0.4)
plt.title("Simpson's 1/3 Rule")
plt.legend()
plt.show()

print("Simpson 1/3 =", I)
# Out:
# Simpson 1/3 = 1.4270270270270269

# %% [markdown]
# # Simpson’s 3/8 Rule

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 1 / (1 + x**2)

def simpson_38(a, b):
    h = (b - a) / 3
    x1 = a + h
    x2 = a + 2*h
    return (b - a) * (f(a) + 3*f(x1) + 3*f(x2) + f(b)) / 8

a, b = 0, 6
I = simpson_38(a, b)

x = np.linspace(a, b, 100)
plt.plot(x, f(x), 'r', label='f(x)')
plt.fill_between(x, f(x), color='salmon', alpha=0.4)
plt.title("Simpson's 3/8 Rule")
plt.legend()
plt.show()

print("Simpson 3/8 =", I)
# Out:
# Simpson 3/8 = 1.352623211446741

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

f = lambda t: 200*np.log(140000/(140000-2100*t)) - 9.8*t
a,b = 8,30
n = 6
h = (b-a)/n
x = np.linspace(a,b,n+1)
y = f(x)
I = 3*h/8*(y[0]+3*sum(y[1:n:3])+3*sum(y[2:n:3])+2*sum(y[3:n-1:3])+y[-1])
print("Simpson 3/8 =", I)

plt.plot(x,y,'o-'); plt.show()
# Out:
# Simpson 3/8 = -2580.6130322702843
